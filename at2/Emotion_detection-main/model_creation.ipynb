# %% [markdown]
# # Emotion Detection

# %% [markdown]
# **Importing Libraries**

# %%
import matplotlib.pyplot as plt
from glob import glob
import cv2
import random
import os
# %matplotlib inline

from tensorflow.keras.preprocessing.image import ImageDataGenerator
from tensorflow.keras.layers import Dense, Input, Dropout, Flatten, Conv2D
from tensorflow.keras.layers import BatchNormalization, Activation, MaxPooling2D
from tensorflow.keras.models import Model, Sequential
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.callbacks import ModelCheckpoint, ReduceLROnPlateau
from tensorflow.keras.utils import plot_model

from IPython.display import SVG, Image
import tensorflow as tf
print("Tensorflow version:", tf.__version__)
# Out:
# Tensorflow version: 2.10.1

# %% [markdown]
# **Exploring Dataset**

# %%
images = glob("train/**/**")
for i in range(9):
    image = random.choice(images)
    plt.figure(figsize=(12,12))
    plt.subplot(331+i)
    plt.imshow(cv2.imread(image));plt.axis('off')

# %% [markdown]
# **Preparing Data for Training**

# %%
img_size = 48
batch_size = 64
datagen_train = ImageDataGenerator()
train_generator = datagen_train.flow_from_directory("train/",
                                                   target_size = (img_size,img_size),
                                                   color_mode = "grayscale",
                                                   batch_size = batch_size,
                                                   class_mode = "categorical",
                                                   shuffle = True)

datagen_validation = ImageDataGenerator()
validation_generator = datagen_train.flow_from_directory("test/",
                                                   target_size = (img_size,img_size),
                                                   color_mode = "grayscale",
                                                   batch_size = batch_size,
                                                   class_mode = "categorical",
                                                   shuffle = True)
# Out:
# Found 28709 images belonging to 7 classes.
# Found 7178 images belonging to 7 classes.

# %% [markdown]
# **Defining Model**

# %%
def Convolution(input_tensor, filters, kernel_size):
    x = Conv2D(filters = filters, kernel_size = kernel_size, padding = "same")(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = MaxPooling2D(pool_size = (2,2))(x)
    x = Dropout(0.25)(x)
    
    return x

# %%
def Dense_f(input_tensor, nodes):
    x = Dense(nodes)(input_tensor)
    x = BatchNormalization()(x)
    x = Activation('relu')(x)
    x = Dropout(0.25)(x)
    
    return x

# %%
def model_fer(input_shape):
    inputs = Input(input_shape)
    conv_1 = Convolution(inputs,32,(3,3))
    conv_2 = Convolution(conv_1,64,(5,5))
    conv_3 = Convolution(conv_2,128,(3,3))

    flatten = Flatten()(conv_3)
    
    dense_1 = Dense_f(flatten,256)

    output  = Dense(7, activation="softmax")(dense_1)
    model  =  Model(inputs=[inputs],outputs = [output])
    
    model.compile(loss=['categorical_crossentropy'] , optimizer = 'adam' , metrics =["accuracy"])

    return model

# %%
model = model_fer((48,48,1))
model.summary()
# Out:
# Model: "model_3"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  input_4 (InputLayer)        [(None, 48, 48, 1)]       0
#
#  conv2d_9 (Conv2D)           (None, 48, 48, 32)        320
#
#  batch_normalization_12 (Bat  (None, 48, 48, 32)       128
#  chNormalization)
#
#  activation_12 (Activation)  (None, 48, 48, 32)        0
#
#  max_pooling2d_9 (MaxPooling  (None, 24, 24, 32)       0
#  2D)
#
#  dropout_12 (Dropout)        (None, 24, 24, 32)        0
#
#  conv2d_10 (Conv2D)          (None, 24, 24, 64)        51264
#
#  batch_normalization_13 (Bat  (None, 24, 24, 64)       256
#  chNormalization)
#
#  activation_13 (Activation)  (None, 24, 24, 64)        0
#
#  max_pooling2d_10 (MaxPoolin  (None, 12, 12, 64)       0
#  g2D)
#
#  dropout_13 (Dropout)        (None, 12, 12, 64)        0
#
#  conv2d_11 (Conv2D)          (None, 12, 12, 128)       73856
#
#  batch_normalization_14 (Bat  (None, 12, 12, 128)      512
#  chNormalization)
#
#  activation_14 (Activation)  (None, 12, 12, 128)       0
#
#  max_pooling2d_11 (MaxPoolin  (None, 6, 6, 128)        0
#  g2D)
#
#  dropout_14 (Dropout)        (None, 6, 6, 128)         0
#
#  flatten_3 (Flatten)         (None, 4608)              0
#
#  dense_6 (Dense)             (None, 256)               1179904
#
#  batch_normalization_15 (Bat  (None, 256)              1024
#  chNormalization)
#
#  activation_15 (Activation)  (None, 256)               0
#
#  dropout_15 (Dropout)        (None, 256)               0
#
#  dense_7 (Dense)             (None, 7)                 1799
#
# =================================================================
# Total params: 1,309,063
# Trainable params: 1,308,103
# Non-trainable params: 960
# _________________________________________________________________

# %% [markdown]
# **Initializing the Model**

# %%
epochs = 15
steps_per_epoch = train_generator.n//train_generator.batch_size
validation_steps = validation_generator.n//validation_generator.batch_size

checkpoint = ModelCheckpoint("model_weights.h5", monitor  ='val_accuracy', save_weights_only = True, mode = 'max', verbose =1)
callbacks = [checkpoint]

# %% [markdown]
# # Traning the Model

# %% [markdown]
# **The next cell takes time to complete**

# %%
history = model.fit(
x = train_generator,
steps_per_epoch = steps_per_epoch,
epochs = epochs,
validation_data = validation_generator,
validation_steps = validation_steps,
callbacks = callbacks)
# Out:
# Epoch 1/15
# 448/448 [==============================] - ETA: 0s - loss: 1.6788 - accuracy: 0.3655
# Epoch 1: saving model to model_weights.h5
# 448/448 [==============================] - 60s 133ms/step - loss: 1.6788 - accuracy: 0.3655 - val_loss: 1.5820 - val_accuracy: 0.4030
# Epoch 2/15
# 448/448 [==============================] - ETA: 0s - loss: 1.3820 - accuracy: 0.4751
# Epoch 2: saving model to model_weights.h5
# 448/448 [==============================] - 7s 15ms/step - loss: 1.3820 - accuracy: 0.4751 - val_loss: 1.3639 - val_accuracy: 0.4742
# Epoch 3/15
# 447/448 [============================>.] - ETA: 0s - loss: 1.2658 - accuracy: 0.5200
# Epoch 3: saving model to model_weights.h5
# 448/448 [==============================] - 7s 15ms/step - loss: 1.2660 - accuracy: 0.5199 - val_loss: 1.3299 - val_accuracy: 0.4997
# Epoch 4/15
# 447/448 [============================>.] - ETA: 0s - loss: 1.1967 - accuracy: 0.5454
# Epoch 4: saving model to model_weights.h5
# 448/448 [==============================] - 7s 15ms/step - loss: 1.1966 - accuracy: 0.5454 - val_loss: 1.2951 - val_accuracy: 0.5109
# Epoch 5/15
# 447/448 [============================>.] - ETA: 0s - loss: 1.1415 - accuracy: 0.5711
# Epoch 5: saving model to model_weights.h5
# 448/448 [==============================] - 7s 16ms/step - loss: 1.1413 - accuracy: 0.5712 - val_loss: 1.2357 - val_accuracy: 0.5289
# Epoch 6/15
# 446/448 [============================>.] - ETA: 0s - loss: 1.0962 - accuracy: 0.5873
# Epoch 6: saving model to model_weights.h5
# 448/448 [==============================] - 7s 16ms/step - loss: 1.0957 - accuracy: 0.5874 - val_loss: 1.2009 - val_accuracy: 0.5476
# Epoch 7/15
# 446/448 [============================>.] - ETA: 0s - loss: 1.0574 - accuracy: 0.6031
# Epoch 7: saving model to model_weights.h5
# 448/448 [==============================] - 7s 17ms/step - loss: 1.0580 - accuracy: 0.6028 - val_loss: 1.1843 - val_accuracy: 0.5572
# Epoch 8/15
# 448/448 [==============================] - ETA: 0s - loss: 1.0122 - accuracy: 0.6216
# Epoch 8: saving model to model_weights.h5
# 448/448 [==============================] - 8s 18ms/step - loss: 1.0122 - accuracy: 0.6216 - val_loss: 1.1108 - val_accuracy: 0.5843
# Epoch 9/15
# 448/448 [==============================] - ETA: 0s - loss: 0.9707 - accuracy: 0.6390
# Epoch 9: saving model to model_weights.h5
# 448/448 [==============================] - 7s 16ms/step - loss: 0.9707 - accuracy: 0.6390 - val_loss: 1.2126 - val_accuracy: 0.5437
# Epoch 10/15
# 445/448 [============================>.] - ETA: 0s - loss: 0.9262 - accuracy: 0.6513
# Epoch 10: saving model to model_weights.h5
# 448/448 [==============================] - 7s 17ms/step - loss: 0.9255 - accuracy: 0.6516 - val_loss: 1.1646 - val_accuracy: 0.5622
# Epoch 11/15
# 446/448 [============================>.] - ETA: 0s - loss: 0.8875 - accuracy: 0.6703
# Epoch 11: saving model to model_weights.h5
# 448/448 [==============================] - 8s 17ms/step - loss: 0.8874 - accuracy: 0.6704 - val_loss: 1.0799 - val_accuracy: 0.5999
# Epoch 12/15
# 446/448 [============================>.] - ETA: 0s - loss: 0.8528 - accuracy: 0.6855
# Epoch 12: saving model to model_weights.h5
# 448/448 [==============================] - 8s 17ms/step - loss: 0.8530 - accuracy: 0.6856 - val_loss: 1.0850 - val_accuracy: 0.6010
# Epoch 13/15
# 445/448 [============================>.] - ETA: 0s - loss: 0.8146 - accuracy: 0.6945
# Epoch 13: saving model to model_weights.h5
# 448/448 [==============================] - 8s 17ms/step - loss: 0.8146 - accuracy: 0.6944 - val_loss: 1.1051 - val_accuracy: 0.5975
# Epoch 14/15
# 445/448 [============================>.] - ETA: 0s - loss: 0.7763 - accuracy: 0.7159
# Epoch 14: saving model to model_weights.h5
# 448/448 [==============================] - 8s 18ms/step - loss: 0.7769 - accuracy: 0.7158 - val_loss: 1.1697 - val_accuracy: 0.5797
# Epoch 15/15
# 448/448 [==============================] - ETA: 0s - loss: 0.7446 - accuracy: 0.7244
# Epoch 15: saving model to model_weights.h5
# 448/448 [==============================] - 8s 17ms/step - loss: 0.7446 - accuracy: 0.7244 - val_loss: 1.0882 - val_accuracy: 0.6140

# %% [markdown]
# **Model Evaluation**

# %%
model.evaluate(validation_generator)
# Out:
# 113/113 [==============================] - 2s 13ms/step - loss: 1.0889 - accuracy: 0.6138
# [1.088891625404358, 0.6138200163841248]

# %% [markdown]
# **Plotting Loss**

# %%
plt.plot(history.history['loss'])
plt.plot(history.history['val_loss'])
plt.title('Model Loss')
plt.legend(['Train','Validation'],loc = 'upper left')
plt.subplots_adjust(top=1.0,bottom=0.0,right =0.95,left=0.0,hspace=0.25,wspace=0.35)

# %%
plt.plot(history.history['accuracy'])
plt.plot(history.history['val_accuracy'])
plt.title('Model Accuracy')
plt.legend(['Train','Validation'],loc = 'upper left')
plt.subplots_adjust(top=1.0,bottom=0.0,right =0.95,left=0.0,hspace=0.25,wspace=0.35)

# %% [markdown]
# **Saving Model**

# %%
model_json = model.to_json()
with open("model_a.json","w") as json_file:
    json_file.write(model_json)
